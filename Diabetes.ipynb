# %% [markdown]
# # Import Dataset

# %%
import tensorflow as tf

# %%
# !pip install PyOpenSSL

# %%
# import csv
# from urllib.request import urlopen

# url = 'https://www.kaggle.com/datasets/rabieelkharoua/diabetes-health-dataset-analysis'
# response = urlopen(url)
# data = response.read()
# data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/Project/Diabetes Classification/diabetes_data.csv')

# %%
df
# Out:
#       PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0          6000   44       0          1                    2               1
# 1          6001   51       1          0                    1               2
# 2          6002   89       1          0                    1               3
# 3          6003   21       1          1                    1               2
# 4          6004   27       1          0                    1               3
# ...         ...  ...     ...        ...                  ...             ...
# 1874       7874   37       0          0                    2               2
# 1875       7875   80       1          0                    2               2
# 1876       7876   38       1          0                    0               2
# 1877       7877   43       0          1                    2               0
# 1878       7878   85       1          0                    2               2
#
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1879 entries, 0 to 1878
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PatientID                      1879 non-null   int64
#  1   Age                            1879 non-null   int64
#  2   Gender                         1879 non-null   int64
#  3   Ethnicity                      1879 non-null   int64
#  4   SocioeconomicStatus            1879 non-null   int64
#  5   EducationLevel                 1879 non-null   int64
#  6   BMI                            1879 non-null   float64
#  7   Smoking                        1879 non-null   int64
#  8   AlcoholConsumption             1879 non-null   float64
#  9   PhysicalActivity               1879 non-null   float64
#  10  DietQuality                    1879 non-null   float64
#  11  SleepQuality                   1879 non-null   float64
# ...

# %%
data = df.drop(columns=['PatientID','Gender','Ethnicity','SocioeconomicStatus','EducationLevel','DoctorInCharge'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1879 entries, 0 to 1878
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1879 non-null   int64
#  1   BMI                            1879 non-null   float64
#  2   Smoking                        1879 non-null   int64
#  3   AlcoholConsumption             1879 non-null   float64
#  4   PhysicalActivity               1879 non-null   float64
#  5   DietQuality                    1879 non-null   float64
#  6   SleepQuality                   1879 non-null   float64
#  7   FamilyHistoryDiabetes          1879 non-null   int64
#  8   GestationalDiabetes            1879 non-null   int64
#  9   PolycysticOvarySyndrome        1879 non-null   int64
#  10  PreviousPreDiabetes            1879 non-null   int64
#  11  Hypertension                   1879 non-null   int64
# ...

# %% [markdown]
# # Pemisahan atribut dan label
#
# y label x atribut

# %%
y = data['Diagnosis'] #ambil diagnosis aja
del data['Diagnosis'] #baru si diagnosis dihapus, jadi sisanya x
x = data
del data

# %% [markdown]
# # Normalisasi

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
scaled_data = scaler.transform(x)
scaled_data = pd.DataFrame(scaled_data, columns = x.columns)
scaled_data
# Out:
#            Age       BMI   Smoking  AlcoholConsumption  PhysicalActivity  \
# 0    -0.538416  0.736909  1.597493           -0.946653         -0.965393
# 1    -0.197125  1.701079 -0.625981           -1.440586          1.085505
# 2     1.655596 -1.099636 -0.625981           -1.508511          0.316010
# 3    -1.659799  0.652280  1.597493           -1.417635          1.206012
# 4    -1.367264 -1.513271 -0.625981            0.907540         -0.200055
# ...        ...       ...       ...                 ...               ...
# 1874 -0.879706 -0.956518 -0.625981            0.143695         -0.694321
# 1875  1.216793  0.000933 -0.625981            1.009924          0.667499
# 1876 -0.830950  1.106295 -0.625981           -0.884793          1.638659
# 1877 -0.587171  0.658697 -0.625981           -0.631469         -0.157798
# 1878  1.460572  0.759142 -0.625981            0.635633          0.081697
#
#       DietQuality  SleepQuality  FamilyHistoryDiabetes  GestationalDiabetes  \
# ...

# %% [markdown]
# # Data Latihan dan Data Train

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(scaled_data, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# # Latih Model
#
# metode logistic regression

# %%
from sklearn import linear_model

model = linear_model.LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Uji akurasi

# %%
model.score(x_test, y_test)
# Out:
# 0.8138297872340425
